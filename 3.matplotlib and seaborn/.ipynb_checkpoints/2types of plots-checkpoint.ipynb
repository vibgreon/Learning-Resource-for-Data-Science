# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
col_names = ['mpg','cylinders','dis','hp','weight',
             'acc','year','origin','name']

# %%
df = pd.read_csv('auto-mpg.data', sep='\s+', names=col_names)
df
# Out:
#       mpg  cylinders    dis     hp  weight   acc  year  origin  \
# 0    18.0          8  307.0  130.0  3504.0  12.0    70       1
# 1    15.0          8  350.0  165.0  3693.0  11.5    70       1
# 2    18.0          8  318.0  150.0  3436.0  11.0    70       1
# 3    16.0          8  304.0  150.0  3433.0  12.0    70       1
# 4    17.0          8  302.0  140.0  3449.0  10.5    70       1
# ..    ...        ...    ...    ...     ...   ...   ...     ...
# 393  27.0          4  140.0  86.00  2790.0  15.6    82       1
# 394  44.0          4   97.0  52.00  2130.0  24.6    82       2
# 395  32.0          4  135.0  84.00  2295.0  11.6    82       1
# 396  28.0          4  120.0  79.00  2625.0  18.6    82       1
# 397  31.0          4  119.0  82.00  2720.0  19.4    82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ...

# %% [markdown]
# ## Histogram Plot

# %%
# Histogram is good for 1D

plt.hist(df['mpg'])
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df['mpg'], bins=20)
plt.xlabel('mpg')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
# scatter is use to see the interaction between 2 variables

# alpha value gives transparency to the plots 

plt.figure(figsize=(10,6))
plt.scatter(x=df['weight'],y=df['mpg'],alpha=0.5)

plt.ylabel('mpg')
plt.xlabel('weight')
plt.show()

# %% [markdown]
# ## Hostogram 2D plot

# %%
# instead of scatter , it shows plot into bins
# when there are mpre points and they're overlapping each other,
# hist2d is a better choice


plt.figure(figsize=(10,6))
plt.hist2d(x=df['weight'],y=df['mpg'])

plt.ylabel('mpg')
plt.xlabel('weight')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Hexagonal Graph

# %%
# gribsize represent size of bins

plt.figure(figsize=(10,6))
plt.hexbin(x=df['weight'],y=df['mpg'], gridsize=(35,15))

plt.ylabel('mpg')
plt.xlabel('weight')
plt.colorbar()
plt.show()

# %%
# cmap to change color

plt.figure(figsize=(10,6))
plt.hexbin(x=df['weight'],y=df['mpg'], gridsize=(35,15), cmap='coolwarm')

plt.ylabel('mpg')
plt.xlabel('weight')
plt.colorbar()
plt.show()
